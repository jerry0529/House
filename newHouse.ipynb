# %%
from bs4 import BeautifulSoup
import requests
import json
import pprint
import time

# %%
niceHouseJson = {}
itemsDetial = {}

# %%
for page in range(1,11):
    
    href = 'https://buy.housefun.com.tw/?hd_CityID=0000&hd_Sequence=SEQUP&hd_SearchGroup=Group01&hd_PM={}'.format(page)
    headers = {'cookie':'SEID_G=2b86728d-04fd-47d7-82fc-72e507b40475; TRID_G=f09cfc46-abe4-4607-abc6-ffa6863ffec8; _ga=GA1.3.827916420.1495961578; _gid=GA1.3.1230402274.1495961578; __ltmwga=utmcsr=google|utmcmd=cpc; __dmwsc=20170500e06ks0000u0000,xao1ii3dr3fmmxddjdgmsgbk,dm00148; ASP.NET_SessionId=xvpej1znaebw4tdmctybq3jt; ez2o_UNID=1495961578633633; WMX_Channel=,3,; objID=; _dc_gtm_UA-22823074-5=1; _ga=GA1.4.827916420.1495961578; _gid=GA1.4.658732106.1495964330; _dc_gtm_UA-34471860-1=1; __ltm_https_flag=true; _uetsid=_uet1cb57764; appier_tp=; appier_utmz=%7B%22csr%22%3A%22www.housefun.com.tw%252F%253Fdmcode%253D20170500e06ks0000u0000%2526gclid%253DCjsKDwjw6qnJBRDpoonDwLSeZhIkAIpTR8IiAziFVXrdzR1VjK0zS7McAOKTRkF-aqm5z9XJ91U8GgIyIvD_BwE%22%7D; appier_uid_2=FKsedFMpt9oC7rt0WgV_rI; appier_pv_countercjEr16Oozn2WXbx=11; _atrk_xuid=e859d80e56d0e944da86a2ba5c0705fce11fe0daab04ad8a644a1b425ef4ab22; _atrk_ssid=dLs568r-QCGEOwydcnt4wz; _atrk_sessidx=104; _atrk_siteuid=ymKIGgSC5bakf4_B'} 
    res = requests.get(href, headers = headers)
    soup = BeautifulSoup(res.text, "lxml")
    sel1 = soup.select('div.m-list-bd > div > section.m-list-obj')
    
    for i in range(0,len(sel1)-1):
        try:
            title = sel1[i].h1.text
            itemsDetial['title'] = title
            #print(title)
        except:
            itemsDetial['title'] = 'no title'
            #print('title not find')
        try:
            subTitle = sel1[i].address.text
            itemsDetial['subTitle'] = subTitle
            #print(subtitle)
        except:
            itemsDetial['subTitle'] = 'no subTitle'
            #print('sub title not find')
        try:
            num = sel1[i].select('em.number')[0].text
            unit = sel1[i].select('em.postfix')[0].text
            itemsDetial['area'] = num + unit
            #print(num + unit)
        except:
            itemsDetial['area'] = 'no area'
            #print('pint not find')
        try:
            floor = sel1[i].select('span.floor')[0].text
            itemsDetial['floor'] = floor
            #print(floor)
        except:
            itemsDetial['floor'] = 'no floor'
            #print('floor not find')
        try:
            pattern = sel1[i].select('em.pattern')[0].text
            itemsDetial['pattern'] = pattern
            #print(pattern)
        except:
            itemsDetial['pattern'] = 'no pattern'
            #print('pattern not find')
        try:
            park = sel1[i].select('em.park')[0].text
            itemsDetial['park'] = park
            #print(park)
        except:
            itemsDetial['park'] = 'no park'
            #print('park not find')
        try:
            priceUnit = sel1[i].select('em.title')[1].text
            price = sel1[i].select('em.wording')[0].text
            itemsDetial['uniPrice'] = priceUnit + price
            #print(priceUnit + price)    
        except:
            itemsDetial['uniPrice'] = 'no uniPrice'
            #print('unit price not find')
        try:
            total = sel1[i].select('em.number')[1].text
            totalUnit = sel1[i].select('em.postfix')[2].text
            itemsDetial['totalPrice'] = '總價' + total + totalUnit      
            #print('總價' + total + totalUnit)
        except:
            itemsDetial['totalPrice'] = 'no totalPrice'
            #print('total price not find')
        #print('==================================================================================')
        niceHouseJson[title] = itemsDetial
    
    time.sleep(2)

# %%
pprint.pprint(niceHouseJson)
# Out:
# {'★住商台北101世貿店~世貿稀有透天豪邸': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '★住商台北101世貿店~北醫高CP值美寓': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '三民捷運武昌新村黃金3樓美寓~格局方正靜巷純住宅~': {'area': '9.88坪',
#                                'floor': '14-14/15樓',
#                                'park': 'no park',
#                                'pattern': '0房(室)1廳1衛',
#                                'subTitle': '台北市中正區羅斯福路二段',
#                                'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                                'totalPrice': '總價980萬',
#                                'uniPrice': '單價99.18萬/坪'},
#  '中社靜園獨棟別墅 稀有庭院景觀別墅': {'area': '9.88坪',
#                        'floor': '14-14/15樓',
#                        'park': 'no park',
#                        'pattern': '0房(室)1廳1衛',
#                        'subTitle': '台北市中正區羅斯福路二段',
#                        'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                        'totalPrice': '總價980萬',
#                        'uniPrice': '單價99.18萬/坪'},
#  '五期高樓景金華苑 漂亮花園金華苑高樓稀有釋出': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '仁愛亞洲第一景 敦南仁愛圓環管理大樓': {'area': '9.88坪',
#                         'floor': '14-14/15樓',
#                         'park': 'no park',
#                         'pattern': '0房(室)1廳1衛',
#                         'subTitle': '台北市中正區羅斯福路二段',
#                         'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                         'totalPrice': '總價980萬',
#                         'uniPrice': '單價99.18萬/坪'},
#  '信義凱悅高樓美景 捷運共構，生活機能佳': {'area': '9.88坪',
#                          'floor': '14-14/15樓',
#                          'park': 'no park',
#                          'pattern': '0房(室)1廳1衛',
#                          'subTitle': '台北市中正區羅斯福路二段',
#                          'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                          'totalPrice': '總價980萬',
#                          'uniPrice': '單價99.18萬/坪'},
#  '信義區面春光公園捷運站後山埤站3房美公寓': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '信義川普名邸【遠眺台北市夜景】+【雙車位】': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '偶像劇聖地 機能方便精美裝潢即可入住': {'area': '9.88坪',
#                         'floor': '14-14/15樓',
#                         'park': 'no park',
#                         'pattern': '0房(室)1廳1衛',
#                         'subTitle': '台北市中正區羅斯福路二段',
#                         'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                         'totalPrice': '總價980萬',
#                         'uniPrice': '單價99.18萬/坪'},
#  '光南獨棟頂樓美寓 一層一戶，稀有頂樓': {'area': '9.88坪',
#                         'floor': '14-14/15樓',
#                         'park': 'no park',
#                         'pattern': '0房(室)1廳1衛',
#                         'subTitle': '台北市中正區羅斯福路二段',
#                         'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                         'totalPrice': '總價980萬',
#                         'uniPrice': '單價99.18萬/坪'},
#  '北科捷運面寬金店 近捷運站傳統市場人潮車潮多': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '南京三民捷運站~民生漾~正面公園邊間格局+大車位': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '南港紐約花園景觀 綠意環繞景觀、南軟捷運旁特殊戶': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '古亭捷運中正觀邸邊間電梯—近古亭捷運站交通機能佳': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '合江透天金店面 華航特區稀有透天': {'area': '9.88坪',
#                       'floor': '14-14/15樓',
#                       'park': 'no park',
#                       'pattern': '0房(室)1廳1衛',
#                       'subTitle': '台北市中正區羅斯福路二段',
#                       'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                       'totalPrice': '總價980萬',
#                       'uniPrice': '單價99.18萬/坪'},
#  '哈密黃金公寓2樓 低總價公寓2樓靜巷住家': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '園區捷運美裝兩房 一層兩戶,邊間,定時警察巡邏': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '圓環邊間黃金三樓 天母蛋黃區低樓層邊間公寓': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '城市花園景觀3房 靜巷高樓視野佳,近萬隆捷運站': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '士林囍堂鑽石三房 士林捷運稀有全新電梯三房打通戶': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '士林四房車新成屋 稀有釋出四房車位新成屋': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '士林捷運精品二樓 近士林夜市 近士林捷運站': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '大安捷運四房美寓 邊間四房黃金三樓漂亮屋況': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '大安雙捷運靜巷-住辦兩用稀有嬕出電梯華廈': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '大湖立委三房美寓 近大湖公園捷運站 邊間三面採光': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '大直CBD,A級商辦整層出售,特大坪數706坪.': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '大華湖閱天韻6樓 私人陽台空中花園': {'area': '9.88坪',
#                        'floor': '14-14/15樓',
#                        'park': 'no park',
#                        'pattern': '0房(室)1廳1衛',
#                        'subTitle': '台北市中正區羅斯福路二段',
#                        'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                        'totalPrice': '總價980萬',
#                        'uniPrice': '單價99.18萬/坪'},
#  '大華湖閱高樓美景 香港B&T設計~一戶一陽台造景': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '大華湖閱高樓豪邸 香港B&T設計!一戶一陽台造景': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '奇岩捷運一豐洲 全新成屋環境佳大賣場及捷運站': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '奇岩捷運邊間三樓 寧靜、格局方正': {'area': '9.88坪',
#                       'floor': '14-14/15樓',
#                       'park': 'no park',
#                       'pattern': '0房(室)1廳1衛',
#                       'subTitle': '台北市中正區羅斯福路二段',
#                       'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                       'totalPrice': '總價980萬',
#                       'uniPrice': '單價99.18萬/坪'},
#  '宏普文德辦公 門面氣派屋齡新內湖科學園區': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '小雅裝潢美屋3房 靜巷後棟近忠孝復興站微風商圈': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '崇偉南京四房車位 稀有四房邊間，一層2戶': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '市府捷運面寬金店 市府商圈正大馬路面寬廣告明顯': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '市府捷運黃金三樓 前後棟距寬 採光良好 格局方正': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '師大路大面寬雙店面~車潮帶動錢潮 高指標性高效益廣': {'area': '9.88坪',
#                                'floor': '14-14/15樓',
#                                'park': 'no park',
#                                'pattern': '0房(室)1廳1衛',
#                                'subTitle': '台北市中正區羅斯福路二段',
#                                'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                                'totalPrice': '總價980萬',
#                                'uniPrice': '單價99.18萬/坪'},
#  '師大金華美寓 交通便利、生活機能佳': {'area': '9.88坪',
#                        'floor': '14-14/15樓',
#                        'park': 'no park',
#                        'pattern': '0房(室)1廳1衛',
#                        'subTitle': '台北市中正區羅斯福路二段',
#                        'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                        'totalPrice': '總價980萬',
#                        'uniPrice': '單價99.18萬/坪'},
#  '延壽林蔭黃金三樓 正面林蔭，黃金三樓': {'area': '9.88坪',
#                         'floor': '14-14/15樓',
#                         'park': 'no park',
#                         'pattern': '0房(室)1廳1衛',
#                         'subTitle': '台北市中正區羅斯福路二段',
#                         'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                         'totalPrice': '總價980萬',
#                         'uniPrice': '單價99.18萬/坪'},
#  '建北長安收租金店 正大馬路、建北長安黃金辦公商圈': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '復興崗捷運小品 稀有近復興崗捷運套房': {'area': '9.88坪',
#                         'floor': '14-14/15樓',
#                         'park': 'no park',
#                         'pattern': '0房(室)1廳1衛',
#                         'subTitle': '台北市中正區羅斯福路二段',
#                         'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                         'totalPrice': '總價980萬',
#                         'uniPrice': '單價99.18萬/坪'},
#  '忠孝復興捷運高樓景觀時尚品味美3房': {'area': '9.88坪',
#                        'floor': '14-14/15樓',
#                        'park': 'no park',
#                        'pattern': '0房(室)1廳1衛',
#                        'subTitle': '台北市中正區羅斯福路二段',
#                        'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                        'totalPrice': '總價980萬',
#                        'uniPrice': '單價99.18萬/坪'},
#  '忠誠邊間美頂家 一層一戶衛浴皆開窗近公園坪數實': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '拾穗景觀樓中樓 高樓景觀使用大空間有露臺': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '捷運一江必賣三樓 公園旁美寓戶數單純': {'area': '9.88坪',
#                         'floor': '14-14/15樓',
#                         'park': 'no park',
#                         'pattern': '0房(室)1廳1衛',
#                         'subTitle': '台北市中正區羅斯福路二段',
#                         'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                         'totalPrice': '總價980萬',
#                         'uniPrice': '單價99.18萬/坪'},
#  '捷運景觀電梯大樓 離捷運約一分鐘生活機能好': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '捷運璀璨圓山凡登 近劍潭捷運站交通和生活機能便利': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '捷運美妝綠意宅 近文德捷運站': {'area': '9.88坪',
#                     'floor': '14-14/15樓',
#                     'park': 'no park',
#                     'pattern': '0房(室)1廳1衛',
#                     'subTitle': '台北市中正區羅斯福路二段',
#                     'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                     'totalPrice': '總價980萬',
#                     'uniPrice': '單價99.18萬/坪'},
#  '捷運高樓景觀三房 生活機能完善近捷運約一分鐘': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '捷運黃金首購3樓 近捷運近公園黃金樓層': {'area': '9.88坪',
#                          'floor': '14-14/15樓',
#                          'park': 'no park',
#                          'pattern': '0房(室)1廳1衛',
#                          'subTitle': '台北市中正區羅斯福路二段',
#                          'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                          'totalPrice': '總價980萬',
#                          'uniPrice': '單價99.18萬/坪'},
#  '換屋誠售出價談稀有光復南路四房晴園華廈': {'area': '9.88坪',
#                          'floor': '14-14/15樓',
#                          'park': 'no park',
#                          'pattern': '0房(室)1廳1衛',
#                          'subTitle': '台北市中正區羅斯福路二段',
#                          'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                          'totalPrice': '總價980萬',
#                          'uniPrice': '單價99.18萬/坪'},
#  '敦南富邑林蔭名邸 敦化南路稀有名邸釋出 面林蔭': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '新婚兩房車位首選 宏普建設低總價近薇閣': {'area': '9.88坪',
#                          'floor': '14-14/15樓',
#                          'park': 'no park',
#                          'pattern': '0房(室)1廳1衛',
#                          'subTitle': '台北市中正區羅斯福路二段',
#                          'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                          'totalPrice': '總價980萬',
#                          'uniPrice': '單價99.18萬/坪'},
#  '新婚首購小永春樓 本社區僅十五樓有此坪數稀有釋出': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '新東美妝收租屋 裝潢新、收租': {'area': '9.88坪',
#                     'floor': '14-14/15樓',
#                     'park': 'no park',
#                     'pattern': '0房(室)1廳1衛',
#                     'subTitle': '台北市中正區羅斯福路二段',
#                     'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                     'totalPrice': '總價980萬',
#                     'uniPrice': '單價99.18萬/坪'},
#  '方正明亮3房好宅~採光通風佳~面公園綠地~': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '昇陽田田美妝電梯三房車位~知名昇陽建設精心打造': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '明德首購百福電梯 鄰近明德捷運、生活機能、環境佳': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '明湖青庭美裝潢 學區、機能、機通皆便利': {'area': '9.88坪',
#                          'floor': '14-14/15樓',
#                          'park': 'no park',
#                          'pattern': '0房(室)1廳1衛',
#                          'subTitle': '台北市中正區羅斯福路二段',
#                          'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                          'totalPrice': '總價980萬',
#                          'uniPrice': '單價99.18萬/坪'},
#  '時代大廈明亮3房(邊間 屋況超美優質住家)': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '有巢世貿店~莊敬稀有電梯二房近北醫、捷運站': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '未來廣慈車庫一樓 大坪數使用實在,方正空間好規劃': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '未來雙子星、五鐵共構玻璃帷幕純辦公大樓': {'area': '9.88坪',
#                          'floor': '14-14/15樓',
#                          'park': 'no park',
#                          'pattern': '0房(室)1廳1衛',
#                          'subTitle': '台北市中正區羅斯福路二段',
#                          'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                          'totalPrice': '總價980萬',
#                          'uniPrice': '單價99.18萬/坪'},
#  '東區管理中庭兩房 雙捷運旁生活機能佳24H管理': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '板南捷運靜巷4房 近後山埤捷運站靜巷裝潢4房3樓': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '林森收租好案 格局方正 采光好 現成2個大套房': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '林森收租好案近捷運、市場，全新裝修！': {'area': '9.88坪',
#                         'floor': '14-14/15樓',
#                         'park': 'no park',
#                         'pattern': '0房(室)1廳1衛',
#                         'subTitle': '台北市中正區羅斯福路二段',
#                         'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                         'totalPrice': '總價980萬',
#                         'uniPrice': '單價99.18萬/坪'},
#  '森林公園辦公一樓 稀有地段釋出住辦店產品': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '極美精緻歐風一樓 社區24小時管理': {'area': '9.88坪',
#                        'floor': '14-14/15樓',
#                        'park': 'no park',
#                        'pattern': '0房(室)1廳1衛',
#                        'subTitle': '台北市中正區羅斯福路二段',
#                        'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                        'totalPrice': '總價980萬',
#                        'uniPrice': '單價99.18萬/坪'},
#  '正面國小三房美寓 鬧中取靜、鄰近南港公園福德國小': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '民權捷運水美璞麗 中山北路一巷住宅生活機能完善': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '民生西路景觀高樓 近雙連捷運站 市場 家樂福': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '水沐青華朝南景觀 SRC鋼骨制震,兆雄璞園開發': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '永春捷運永春市場優質國泰名人高樓加車位': {'area': '9.88坪',
#                          'floor': '14-14/15樓',
#                          'park': 'no park',
#                          'pattern': '0房(室)1廳1衛',
#                          'subTitle': '台北市中正區羅斯福路二段',
#                          'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                          'totalPrice': '總價980萬',
#                          'uniPrice': '單價99.18萬/坪'},
#  '永春捷運站三角住辦世貿IC邊間辦公室美妝踩光帶車位': {'area': '9.88坪',
#                                'floor': '14-14/15樓',
#                                'park': 'no park',
#                                'pattern': '0房(室)1廳1衛',
#                                'subTitle': '台北市中正區羅斯福路二段',
#                                'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                                'totalPrice': '總價980萬',
#                                'uniPrice': '單價99.18萬/坪'},
#  '湯布院芬多精美屋 高檔檜木裝潢 戶數少環境單純': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '濱江市場,松江市場,花博公園,超低總價德惠街金店面': {'area': '9.88坪',
#                                'floor': '14-14/15樓',
#                                'park': 'no park',
#                                'pattern': '0房(室)1廳1衛',
#                                'subTitle': '台北市中正區羅斯福路二段',
#                                'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                                'totalPrice': '總價980萬',
#                                'uniPrice': '單價99.18萬/坪'},
#  '獨棟一層一戶方正朝南近忠誠公園SOGO芝山捷運': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '皇家庭院挑高美居 靜巷內前庭後院挑高設計': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '皇族富貴方正四房 漂亮高樓層獨棟雙併美四房': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '紀念館名邸附車位 附有坡道平面車位可停雙車': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'},
#  '羅馬儷園管理三房 雙公園環繞三玉國小天母國中': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '美校庭院車庫一樓 近美校日僑靜巷大庭院好停車': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '美麗華綠意三房 近美麗華商圈靜巷社區單純邊間': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '耕曦小品景觀戶 面後棟 景觀佳': {'area': '9.88坪',
#                      'floor': '14-14/15樓',
#                      'park': 'no park',
#                      'pattern': '0房(室)1廳1衛',
#                      'subTitle': '台北市中正區羅斯福路二段',
#                      'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                      'totalPrice': '總價980萬',
#                      'uniPrice': '單價99.18萬/坪'},
#  '自力新婚首選小宅 近公園公車站低總價入住北市': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '艷冠風水裝潢四房 蓮園建設，一層兩戶，豪宅規格': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '芝山捷運邊間三房 芝山捷運旁  公園靜巷': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '芸廬三房管理美廈 近六張犁捷運，有管理電梯三房': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '華固挑高兩房車位 挑高3米6格局方正兩房': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '華固綠地電梯三房 華固公園旁電梯高樓三房加車位': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '萊茵尊品兩房車 近捷運北投區通風採光佳': {'area': '9.88坪',
#                          'floor': '14-14/15樓',
#                          'park': 'no park',
#                          'pattern': '0房(室)1廳1衛',
#                          'subTitle': '台北市中正區羅斯福路二段',
#                          'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                          'totalPrice': '總價980萬',
#                          'uniPrice': '單價99.18萬/坪'},
#  '萬大路面寬店面 面寬 採光好 空間大 熱鬧店面': {'area': '9.88坪',
#                              'floor': '14-14/15樓',
#                              'park': 'no park',
#                              'pattern': '0房(室)1廳1衛',
#                              'subTitle': '台北市中正區羅斯福路二段',
#                              'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                              'totalPrice': '總價980萬',
#                              'uniPrice': '單價99.18萬/坪'},
#  '葫洲捷運綠蔭美居 麗湖學區挑高魔術大空間': {'area': '9.88坪',
#                           'floor': '14-14/15樓',
#                           'park': 'no park',
#                           'pattern': '0房(室)1廳1衛',
#                           'subTitle': '台北市中正區羅斯福路二段',
#                           'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                           'totalPrice': '總價980萬',
#                           'uniPrice': '單價99.18萬/坪'},
#  '農安公園電梯三房 稀有國泰建設釋出格局超方正': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '遠砌管理景觀花園 科技大樓旁大安遠砌裝潢美屋': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '部落格山景 景觀棟距遠': {'area': '9.88坪',
#                  'floor': '14-14/15樓',
#                  'park': 'no park',
#                  'pattern': '0房(室)1廳1衛',
#                  'subTitle': '台北市中正區羅斯福路二段',
#                  'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                  'totalPrice': '總價980萬',
#                  'uniPrice': '單價99.18萬/坪'},
#  '鋼骨南海院美豪邸 鄰植物園，正面建中綠蔭大戶': {'area': '9.88坪',
#                             'floor': '14-14/15樓',
#                             'park': 'no park',
#                             'pattern': '0房(室)1廳1衛',
#                             'subTitle': '台北市中正區羅斯福路二段',
#                             'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                             'totalPrice': '總價980萬',
#                             'uniPrice': '單價99.18萬/坪'},
#  '陽明醫院馬路店面 近國小附近商家林立': {'area': '9.88坪',
#                         'floor': '14-14/15樓',
#                         'park': 'no park',
#                         'pattern': '0房(室)1廳1衛',
#                         'subTitle': '台北市中正區羅斯福路二段',
#                         'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                         'totalPrice': '總價980萬',
#                         'uniPrice': '單價99.18萬/坪'},
#  '面綠大地景觀三房 正面六千坪綠地景觀高樓稀有釋出': {'area': '9.88坪',
#                               'floor': '14-14/15樓',
#                               'park': 'no park',
#                               'pattern': '0房(室)1廳1衛',
#                               'subTitle': '台北市中正區羅斯福路二段',
#                               'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                               'totalPrice': '總價980萬',
#                               'uniPrice': '單價99.18萬/坪'},
#  '龍安龍門星雲大樓 面森林公園有管理代收垃圾': {'area': '9.88坪',
#                            'floor': '14-14/15樓',
#                            'park': 'no park',
#                            'pattern': '0房(室)1廳1衛',
#                            'subTitle': '台北市中正區羅斯福路二段',
#                            'title': '古亭捷運師大麗緻電梯高樓—收租投資自用皆宜',
#                            'totalPrice': '總價980萬',
#                            'uniPrice': '單價99.18萬/坪'}}

# %%
len(niceHouseJson)
# Out:
# 100
